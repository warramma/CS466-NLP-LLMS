# %%
2+2
# Out:
# 4

# %%
x = 2

# %%
print(x)
# Out:
# 2

# %% [markdown]
# # notes
# - a for above, b for below cell creation
# - item 1
# - item 2

# %% [markdown]
# ## Create the environment

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["GEMINI_API_KEY"]== os.getenv("GEMINI_API_KEY")
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="gemini-3.6-flash", model_provider="google_genai")
model
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.6.1', 'langchain': '1.3.18', 'langchain-google-genai': '4.3.7'}}, profile={'name': 'Gemini 3.6 Flash', 'release_date': '2026-07-21', 'last_updated': '2026-07-21', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True, 'reasoning_effort_levels': ['minimal', 'low', 'medium', 'high'], 'reasoning_effort_default': 'medium'}, google_api_key=SecretStr('**********'), model='gemini-3.6-flash', temperature=None, client=<google.genai.client.Client object at 0x000001BDCF6B6900>, default_metadata=(), model_kwargs={})

# %%
response = model.invoke("Hi").content
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
response
# Out:
# [{'type': 'text',
#   'text': 'Hello! How can I help you today?',
#   'extras': {'signature': '...'}}]

# %%
response[0]['text']
# Out:
# 'Hello! How can I help you today?'

# %%
model.invoke("Who won the FIFA 2026 world cup?").content[0]['text']
# Out:
# 'The FIFA World Cup 2026 has not taken place yet, so there is no winner. \n\nIt is scheduled to be hosted jointly by Canada, Mexico, and the United States in June and July 2026.'
